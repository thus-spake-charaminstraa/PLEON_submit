# %% [markdown]
# <h1> label txt 추출

# %%
weights_path='/Users/junehyeok/HYEOKIKI/SOMA/plantDetection/yolov5/runs/train/leaf0808/weights/best.pt'
source_path='/Users/junehyeok/HYEOKIKI/SOMA/leaf_dataset/leaf/images/0806'
project_path='/Users/junehyeok/HYEOKIKI/SOMA/leaf_dataset/record'
name_path='0810_result'

# %%
# !python /Users/junehyeok/HYEOKIKI/SOMA/plantDetection/yolov5/detect.py --weights "$weights_path" --img 640 --conf 0.2 --source "$source_path" --project "$project_path" --save-txt --exist-ok --name "$name_path"
# Out:
# detect: weights=['/Users/junehyeok/HYEOKIKI/SOMA/plantDetection/yolov5/runs/train/leaf0808/weights/best.pt'], source=/Users/junehyeok/HYEOKIKI/SOMA/leaf_dataset/leaf/images/0806, data=../plantDetection/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/Users/junehyeok/HYEOKIKI/SOMA/leaf_dataset/record, name=0810_result, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-7-5 Python-3.9.13 torch-1.11.0 CPU
#
# Fusing layers...
# YOLOv5s_leaf summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/13213 /Users/junehyeok/HYEOKIKI/SOMA/leaf_dataset/leaf/images/0806/00a6039c-e425-4f7d-81b1-d6b0e668517e___RS_HL-7669_JPG.rf.b4c0a435ae1ff83c21d6ac9d5d5ab9d5.jpg: 640x640 1 leaf, Done. (0.077s)
# ...
